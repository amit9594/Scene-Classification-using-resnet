# %%
# !pip install -q kaggle

# %%
# from google.colab import files
# files.upload()
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
# ...
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\AMIT\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                               title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# datasets/ankanhore545/cost-of-living-index-2022                   Cost of Living Index 2022                           176KB  2022-03-26 04:56:04           1499         22  1.0
# datasets/piterfm/2022-ukraine-russian-war                         2022 Ukraine Russia War                               2KB  2022-04-02 13:30:10           4379        277  1.0
# datasets/kuchhbhi/latest-laptop-price-list                        Latest Laptop Price List                             19KB  2022-04-03 02:38:35            713         22  1.0
# datasets/kamilpytlak/personal-key-indicators-of-heart-disease     Personal Key Indicators of Heart Disease              3MB  2022-02-16 10:18:03           6970        151  1.0
# datasets/prasertk/historical-commodity-prices-from-20002022       Major commodity prices from 2000-2022               388KB  2022-03-31 05:55:38            450         17  1.0
# datasets/timmofeyy/-tesla-daily-stocks-prices                     🚗 Tesla Daily Stocks Prices                          57KB  2022-03-29 12:55:27            524         24  1.0
# datasets/xhlulu/cpc-codes                                         Cooperative Patent Classification Codes Meaning       5MB  2022-03-22 03:04:36            232         53  1.0
# datasets/ivanchvez/causes-of-death-our-world-in-data              Causes of Death - Our World In Data                   1MB  2022-03-29 18:35:21            478         18  0.9705882
# datasets/prasertk/healthy-lifestyle-cities-report-2021            Healthy Lifestyle Cities Report 2021                  2KB  2022-03-03 00:26:02           3645        105  1.0
# datasets/timmofeyy/-fire-cases-in-uk-within-last-3-years          🔥 Fire Cases in UK within last 3 Years               22MB  2022-03-30 20:49:24            223         12  1.0
# datasets/ajaypalsinghlo/world-happiness-report-2022               world happiness report 2022                           5KB  2022-03-21 13:41:15           1257         37  0.9705882
# datasets/vardhansiramdasu/fraudulent-transactions-prediction      Fraudulent Transactions Prediction                  178MB  2022-03-21 16:08:45            816         36  1.0
# datasets/anandhuh/population-data-china                           Population of China (2020 and historical)             3KB  2022-03-30 16:17:29            215         27  1.0
# datasets/vivek468/superstore-dataset-final                        Superstore Dataset                                  550KB  2022-02-17 11:33:07           5474        126  1.0
# datasets/prasertk/sunshine-duration-by-city                       Sunshine duration by city                            15KB  2022-03-29 01:57:44            398         21  1.0
# datasets/zgrcemta/world-gdpgdp-gdp-per-capita-and-annual-growths  World GDP(GDP, GDP per capita, and annual growths)  556KB  2022-03-19 17:47:43            667         21  0.9411765
# datasets/ashishjangra27/ted-talks                                 TED Talks                                           298KB  2022-02-23 15:16:08           3216        140  1.0
# datasets/equinxx/spotify-top-50-songs-in-2021                     Spotify top 50 songs in 2021                          4KB  2022-03-17 22:59:45           1912         57  1.0
# datasets/pranalibose/amazon-seller-order-status-prediction        Amazon Seller - Order Status Prediction              23KB  2022-02-26 06:31:07           3252         84  0.88235295
# datasets/mrdaniilak/russia-real-estate-2021                       Russia Real Estate 2021                             276MB  2022-03-29 23:21:10            203         21  1.0

# %%
#!kaggle datasets download -d lash45/sun397-50-50

# %%
# !kaggle datasets download -d lash45/sun397-50-50
# Out:
# Downloading sun397-50-50.zip to /content
# 100% 11.5G/11.5G [01:29<00:00, 185MB/s]
# 100% 11.5G/11.5G [01:29<00:00, 137MB/s]

# %%
# !unzip /content/sun397-50-50.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train
#   inflating: train/train/youth_hostel/sun_brkaleiziezkyrbc.jpg
#   inflating: train/train/youth_hostel/sun_brnuucpldzxiujpi.jpg
#   inflating: train/train/youth_hostel/sun_bsfjquzxrikccygm.jpg
#   inflating: train/train/youth_hostel/sun_bsqvztdbgceapyzn.jpg
#   inflating: train/train/youth_hostel/sun_bukrskzdqpbyiolq.jpg

# %% [markdown]
# # For train set:

# %%
import os

base = '/content/train/train'

folders = os.listdir(base)

all_filenames = []

for folder_name in folders:

    # add base path to folder name to have full path
    full_path = os.path.join(base, folder_name)
    print(full_path)
    
    # get filenames (without path) in folder
    # filenames = os.listdir(full_path)
    
    # add path to filenames
    # filenames = [os.path.join(full_path, name) for name in filenames]
   
    all_filenames.append(full_path)
    
print(all_filenames)
# Out:
# /content/train/train/athletic_field_outdoor
# /content/train/train/thriftshop
# /content/train/train/wet_bar
# /content/train/train/cottage_garden
# /content/train/train/tennis_court_outdoor
# /content/train/train/herb_garden
# /content/train/train/butchers_shop
# /content/train/train/utility_room
# /content/train/train/clean_room
# /content/train/train/oil_refinery
# /content/train/train/synagogue_outdoor
# /content/train/train/childs_room
# /content/train/train/corridor
# /content/train/train/gas_station
# /content/train/train/wrestling_ring_indoor
# /content/train/train/wind_farm
# /content/train/train/escalator
# /content/train/train/ruin
# /content/train/train/office_building
# /content/train/train/dinette_home
# /content/train/train/formal_garden
# /content/train/train/residential_neighbourhood
# /content/train/train/basement
# /content/train/train/airport_terminal
# /content/train/train/food_court
# /content/train/train/church_indoor
# /content/train/train/field_wild
# /content/train/train/wave
# /content/train/train/ball_pit
# /content/train/train/arch
# /content/train/train/locker_room
# /content/train/train/elevator_shaft
# /content/train/train/marsh
# /content/train/train/schoolhouse
# /content/train/train/medina
# /content/train/train/casino
# /content/train/train/wheat_field
# /content/train/train/landing_deck
# /content/train/train/sky
# /content/train/train/game_room
# /content/train/train/campsite
# /content/train/train/cathedral_outdoor
# /content/train/train/museum
# /content/train/train/attic
# /content/train/train/house
# /content/train/train/heliport
# /content/train/train/mausoleum
# /content/train/train/beauty_salon
# /content/train/train/archive
# /content/train/train/basketball_court_outdoor
# /content/train/train/library_indoor
# /content/train/train/inn
# /content/train/train/pasture
# /content/train/train/youth_hostel
# /content/train/train/topiary_garden
# /content/train/train/fairway
# /content/train/train/art_school
# /content/train/train/poolroom_establishment
# /content/train/train/underwater_coral_reef
# /content/train/train/boardwalk
# /content/train/train/hangar_outdoor
# /content/train/train/temple_south_asia
# /content/train/train/carrousel
# /content/train/train/jacuzzi
# /content/train/train/pagoda
# /content/train/train/cabin
# /content/train/train/courthouse
# /content/train/train/canal_natural
# /content/train/train/cubicle
# /content/train/train/assembly_line
# /content/train/train/sandbar
# /content/train/train/cemetery
# /content/train/train/banquet_hall
# /content/train/train/outhouse
# /content/train/train/jail
# /content/train/train/drugstore
# /content/train/train/cathedral_indoor
# /content/train/train/manufactured_home
# /content/train/train/stadium_football
# /content/train/train/ice_floe
# /content/train/train/office
# /content/train/train/hospital_room
# /content/train/train/temple_east_asia
# /content/train/train/fire_station
# /content/train/train/courtyard
# /content/train/train/motel
# /content/train/train/river
# /content/train/train/beach
# /content/train/train/shower
# /content/train/train/hotel_room
# /content/train/train/art_studio
# /content/train/train/amusement_park
# /content/train/train/industrial_area
# /content/train/train/wine_cellar_barrel_storrage
# /content/train/train/watering_hole
# /content/train/train/snowfield
# /content/train/train/auto_factory
# /content/train/train/canal_urban
# /content/train/train/vineyard
# /content/train/train/biology_laboratory
# /content/train/train/iceberg
# /content/train/train/subway_interior
# /content/train/train/baseball_field
# /content/train/train/chicken_coop_indoor
# /content/train/train/subway_station
# /content/train/train/hangar_indoor
# /content/train/train/doorway
# /content/train/train/market_outdoor
# /content/train/train/field_cultivated
# /content/train/train/ocean
# /content/train/train/kindergarden_classroom
# /content/train/train/monastery
# /content/train/train/parking_lot
# /content/train/train/butte
# /content/train/train/volleyball_court_outdoor
# /content/train/train/mansion
# /content/train/train/brewery_indoor
# /content/train/train/ice_cream_parlor
# /content/train/train/islet
# /content/train/train/parlor
# /content/train/train/home_office
# /content/train/train/aqueduct
# /content/train/train/shed
# /content/train/train/abbey
# /content/train/train/building_facade
# /content/train/train/theater_indoor_seats
# /content/train/train/pharmacy
# /content/train/train/valley
# /content/train/train/bookstore
# /content/train/train/desert_vegetation
# /content/train/train/shoe_shop
# /content/train/train/sandbox
# /content/train/train/runway
# /content/train/train/lake_natural
# /content/train/train/apartment_building_outdoor
# /content/train/train/bowling_alley
# /content/train/train/dinette_vehicle
# /content/train/train/discotheque
# /content/train/train/dining_car
# /content/train/train/courtroom
# /content/train/train/podium_indoor
# /content/train/train/construction_site
# /content/train/train/promenade_deck
# /content/train/train/driveway
# /content/train/train/cavern
# /content/train/train/bakery_shop
# /content/train/train/hotel
# /content/train/train/aquarium
# /content/train/train/greenhouse_indoor
# /content/train/train/harbor
# /content/train/train/highway
# /content/train/train/mosque_indoor
# /content/train/train/vegetable_garden
# /content/train/train/dining_room
# /content/train/train/music_studio
# /content/train/train/throne_room
# /content/train/train/pond
# /content/train/train/pilothouse
# /content/train/train/skyscraper
# /content/train/train/bridge
# /content/train/train/apse_indoor
# /content/train/train/wine_cellar_bottle_storage
# /content/train/train/control_tower
# /content/train/train/park
# /content/train/train/elevator_interior
# /content/train/train/crevasse
# /content/train/train/art_gallery
# /content/train/train/viaduct
# /content/train/train/living_room
# /content/train/train/jewelry_shop
# /content/train/train/computer_room
# /content/train/train/car_interior_frontseat
# /content/train/train/baggage_claim
# /content/train/train/swamp
# /content/train/train/stable
# /content/train/train/nuclear_power_plant
# /content/train/train/water_tower
# /content/train/train/hot_tub
# /content/train/train/firing_range
# /content/train/train/castle
# /content/train/train/plaza
# /content/train/train/stage
# /content/train/train/windmill
# /content/train/train/pantry
# /content/train/train/supermarket
# /content/train/train/yard
# /content/train/train/pavilion
# /content/train/train/picnic_area
# /content/train/train/dam
# /content/train/train/hunting_lodge
# /content/train/train/toll_plaza
# /content/train/train/library_outdoor
# /content/train/train/arrival_gate_outdoor
# /content/train/train/ski_slope
# /content/train/train/landfill
# /content/train/train/tree_house
# /content/train/train/physics_laboratory
# /content/train/train/raft
# /content/train/train/chemistry_lab
# /content/train/train/oilrig
# /content/train/train/tennis_court_indoor
# /content/train/train/amusement_arcade
# /content/train/train/train_railway
# /content/train/train/botanical_garden
# /content/train/train/forest_road
# /content/train/train/patio
# /content/train/train/garbage_dump
# /content/train/train/barn
# /content/train/train/bow_window_outdoor
# /content/train/train/trench
# /content/train/train/power_plant
# /content/train/train/conference_center
# /content/train/train/village
# /content/train/train/reception
# /content/train/train/tent
# /content/train/train/rock_arch
# /content/train/train/engine_room
# /content/train/train/bistro_indoor
# /content/train/train/street
# /content/train/train/delicatessen
# /content/train/train/dock
# /content/train/train/limousine_interior
# /content/train/train/classroom
# /content/train/train/kitchenette
# /content/train/train/orchard
# /content/train/train/chicken_coop_outdoor
# /content/train/train/hill
# /content/train/train/alley
# /content/train/train/cheese_factory
# /content/train/train/warehouse_indoor
# /content/train/train/car_interior_backseat
# /content/train/train/escavation
# /content/train/train/clothing_store
# /content/train/train/bedroom
# /content/train/train/pulpit
# /content/train/train/ice_skating_rink_outdoor
# /content/train/train/corn_field
# /content/train/train/amphitheater
# /content/train/train/lighthouse
# /content/train/train/driving_range
# /content/train/train/closet
# /content/train/train/church_outdoor
# /content/train/train/factory
# /content/train/train/fire_escape
# /content/train/train/bus_interior
# /content/train/train/volcano
# /content/train/train/palace
# /content/train/train/oast_house
# /content/train/train/ticket_booth
# /content/train/train/catacomb
# /content/train/train/lecture_room
# /content/train/train/candy_store
# /content/train/train/badlands
# /content/train/train/crosswalk
# /content/train/train/playroom
# /content/train/train/phone_booth
# /content/train/train/forest_needleleaf
# /content/train/train/hayfield
# /content/train/train/dentists_office
# /content/train/train/railroad_track
# /content/train/train/waterfall_plunge
# /content/train/train/mosque_outdoor
# /content/train/train/train_station
# /content/train/train/lock_chamber
# /content/train/train/lobby
# /content/train/train/airplane_cabin
# /content/train/train/tree_farm
# /content/train/train/garage
# /content/train/train/control_room
# /content/train/train/television_studio
# /content/train/train/slum
# /content/train/train/ski_lodge
# /content/train/train/observatory
# /content/train/train/raceway
# /content/train/train/tower
# /content/train/train/swimming_pool_indoor
# /content/train/train/laundromat
# /content/train/train/squash_court
# /content/train/train/veranda
# /content/train/train/bullring
# /content/train/train/nursery
# /content/train/train/conference_room
# /content/train/train/volleyball_court_indoor
# /content/train/train/igloo
# /content/train/train/ice_shelf
# /content/train/train/desert_sand
# /content/train/train/forest_broadleaf
# /content/train/train/golf_course
# /content/train/train/theater_indoor_procenium
# /content/train/train/riding_arena
# /content/train/train/podium_outdoor
# /content/train/train/diner_indoor
# /content/train/train/rainforest
# /content/train/train/chalet
# /content/train/train/poolroom_home
# /content/train/train/boathouse
# /content/train/train/cloister
# /content/train/train/rope_bridge
# /content/train/train/campus
# /content/train/train/gazebo
# /content/train/train/booth_indoor
# /content/train/train/operating_room
# /content/train/train/music_store
# /content/train/train/skatepark
# /content/train/train/lido_deck
# /content/train/train/ballroom
# /content/train/train/hot_spring
# /content/train/train/gymnasium
# /content/train/train/recreation_room
# /content/train/train/galley
# /content/train/train/playground
# /content/train/train/lift_bridge
# /content/train/train/basilica
# /content/train/train/market_indoor
# /content/train/train/track
# /content/train/train/martial_arts_gym
# /content/train/train/boxing_ring
# /content/train/train/parking_garage_indoor
# /content/train/train/putting_green
# /content/train/train/coast
# /content/train/train/bow_window_indoor
# /content/train/train/coffe_shop
# /content/train/train/mountain_snowy
# /content/train/train/creek
# /content/train/train/sea_cliff
# /content/train/train/moat
# /content/train/train/batters_box
# /content/train/train/videostore
# /content/train/train/planetarium
# /content/train/train/kitchen
# /content/train/train/kennel_indoor
# /content/train/train/van_interior
# /content/train/train/general_store_outdoor
# /content/train/train/restaurant_kitchen
# /content/train/train/berth
# /content/train/train/cockpit
# /content/train/train/hospital
# /content/train/train/sauna
# /content/train/train/bamboo_forest
# /content/train/train/swimming_pool_outdoor
# /content/train/train/ski_resort
# /content/train/train/rice_paddy
# /content/train/train/waterfall_block
# /content/train/train/stadium_baseball
# /content/train/train/boat_deck
# /content/train/train/ice_skating_rink_indoor
# /content/train/train/jail_cell
# /content/train/train/movie_theater
# /content/train/train/bathroom
# /content/train/train/barndoor
# /content/train/train/badminton_court_indoor
# /content/train/train/fastfood_restaurant
# /content/train/train/sushi_bar
# /content/train/train/server_room
# /content/train/train/restaurant_patio
# /content/train/train/balcony_exterior
# /content/train/train/veterinarians_office
# /content/train/train/atrium_public
# /content/train/train/diner_outdoor
# /content/train/train/burial_chamber
# /content/train/train/racecourse
# /content/train/train/electrical_substation
# /content/train/train/forest_path
# /content/train/train/waiting_room
# /content/train/train/cafeteria
# /content/train/train/general_store_indoor
# /content/train/train/restaurant
# /content/train/train/toyshop
# /content/train/train/dorm_room
# /content/train/train/cliff
# /content/train/train/kennel_outdoor
# /content/train/train/bazaar_indoor
# /content/train/train/anechoic_chamber
# /content/train/train/gift_shop
# /content/train/train/bar
# /content/train/train/shopping_mall
# /content/train/train/florist_shop
# /content/train/train/pub
# /content/train/train/balcony_interior
# /content/train/train/bazaar_outdoor
# /content/train/train/staircase
# /content/train/train/synagogue_indoor
# /content/train/train/covered_bridge
# /content/train/train/waterfall_fan
# /content/train/train/parking_garage_outdoor
# /content/train/train/elevator_door
# /content/train/train/kasbah
# /content/train/train/shopfront
# /content/train/train/labyrinth
# /content/train/train/mountain
# /content/train/train/greenhouse_outdoor
# /content/train/train/bayou
# /content/train/train/canyon
# /content/train/train/fountain
# /content/train/train/fishpond
# /content/train/train/corral
# /content/train/train/auditorium
# ['/content/train/train/athletic_field_outdoor', '/content/train/train/thriftshop', '/content/train/train/wet_bar', '/content/train/train/cottage_garden', '/content/train/train/tennis_court_outdoor', '/content/train/train/herb_garden', '/content/train/train/butchers_shop', '/content/train/train/utility_room', '/content/train/train/clean_room', '/content/train/train/oil_refinery', '/content/train/train/synagogue_outdoor', '/content/train/train/childs_room', '/content/train/train/corridor', '/content/train/train/gas_station', '/content/train/train/wrestling_ring_indoor', '/content/train/train/wind_farm', '/content/train/train/escalator', '/content/train/train/ruin', '/content/train/train/office_building', '/content/train/train/dinette_home', '/content/train/train/formal_garden', '/content/train/train/residential_neighbourhood', '/content/train/train/basement', '/content/train/train/airport_terminal', '/content/train/train/food_court', '/content/train/train/church_indoor', '/content/train/train/field_wild', '/content/train/train/wave', '/content/train/train/ball_pit', '/content/train/train/arch', '/content/train/train/locker_room', '/content/train/train/elevator_shaft', '/content/train/train/marsh', '/content/train/train/schoolhouse', '/content/train/train/medina', '/content/train/train/casino', '/content/train/train/wheat_field', '/content/train/train/landing_deck', '/content/train/train/sky', '/content/train/train/game_room', '/content/train/train/campsite', '/content/train/train/cathedral_outdoor', '/content/train/train/museum', '/content/train/train/attic', '/content/train/train/house', '/content/train/train/heliport', '/content/train/train/mausoleum', '/content/train/train/beauty_salon', '/content/train/train/archive', '/content/train/train/basketball_court_outdoor', '/content/train/train/library_indoor', '/content/train/train/inn', '/content/train/train/pasture', '/content/train/train/youth_hostel', '/content/train/train/topiary_garden', '/content/train/train/fairway', '/content/train/train/art_school', '/content/train/train/poolroom_establishment', '/content/train/train/underwater_coral_reef', '/content/train/train/boardwalk', '/content/train/train/hangar_outdoor', '/content/train/train/temple_south_asia', '/content/train/train/carrousel', '/content/train/train/jacuzzi', '/content/train/train/pagoda', '/content/train/train/cabin', '/content/train/train/courthouse', '/content/train/train/canal_natural', '/content/train/train/cubicle', '/content/train/train/assembly_line', '/content/train/train/sandbar', '/content/train/train/cemetery', '/content/train/train/banquet_hall', '/content/train/train/outhouse', '/content/train/train/jail', '/content/train/train/drugstore', '/content/train/train/cathedral_indoor', '/content/train/train/manufactured_home', '/content/train/train/stadium_football', '/content/train/train/ice_floe', '/content/train/train/office', '/content/train/train/hospital_room', '/content/train/train/temple_east_asia', '/content/train/train/fire_station', '/content/train/train/courtyard', '/content/train/train/motel', '/content/train/train/river', '/content/train/train/beach', '/content/train/train/shower', '/content/train/train/hotel_room', '/content/train/train/art_studio', '/content/train/train/amusement_park', '/content/train/train/industrial_area', '/content/train/train/wine_cellar_barrel_storrage', '/content/train/train/watering_hole', '/content/train/train/snowfield', '/content/train/train/auto_factory', '/content/train/train/canal_urban', '/content/train/train/vineyard', '/content/train/train/biology_laboratory', '/content/train/train/iceberg', '/content/train/train/subway_interior', '/content/train/train/baseball_field', '/content/train/train/chicken_coop_indoor', '/content/train/train/subway_station', '/content/train/train/hangar_indoor', '/content/train/train/doorway', '/content/train/train/market_outdoor', '/content/train/train/field_cultivated', '/content/train/train/ocean', '/content/train/train/kinder ...

# %%
len(all_filenames)
import shutil
for i in all_filenames[:297]:
    shutil.rmtree(i)

# %%
len(all_filenames)
# Out:
# 397

# %%
from glob import glob
train_path = '/content/train/train'

# useful for getting number of classes
folders = glob(train_path + '/*')
len(folders)
# Out:
# 100

# %% [markdown]
# # For test set

# %%
import os

base = '/content/test/test'

folders = os.listdir(base)

all_test_filenames = []

for folder_name in folders:

    # add base path to folder name to have full path
    full_path = os.path.join(base, folder_name)
    print(full_path)
    
    # get filenames (without path) in folder
    # filenames = os.listdir(full_path)
    
    # add path to filenames
    # filenames = [os.path.join(full_path, name) for name in filenames]
   
    all_test_filenames.append(full_path)
    
print(all_test_filenames)
# Out:
# /content/test/test/athletic_field_outdoor
# /content/test/test/thriftshop
# /content/test/test/wet_bar
# /content/test/test/cottage_garden
# /content/test/test/tennis_court_outdoor
# /content/test/test/herb_garden
# /content/test/test/butchers_shop
# /content/test/test/utility_room
# /content/test/test/clean_room
# /content/test/test/oil_refinery
# /content/test/test/synagogue_outdoor
# /content/test/test/childs_room
# /content/test/test/corridor
# /content/test/test/gas_station
# /content/test/test/wrestling_ring_indoor
# /content/test/test/wind_farm
# /content/test/test/escalator
# /content/test/test/ruin
# /content/test/test/office_building
# /content/test/test/dinette_home
# /content/test/test/formal_garden
# /content/test/test/residential_neighbourhood
# /content/test/test/basement
# /content/test/test/airport_terminal
# /content/test/test/food_court
# /content/test/test/church_indoor
# /content/test/test/field_wild
# /content/test/test/wave
# /content/test/test/ball_pit
# /content/test/test/arch
# /content/test/test/locker_room
# /content/test/test/elevator_shaft
# /content/test/test/marsh
# /content/test/test/schoolhouse
# /content/test/test/medina
# /content/test/test/casino
# /content/test/test/wheat_field
# /content/test/test/landing_deck
# /content/test/test/sky
# /content/test/test/game_room
# /content/test/test/campsite
# /content/test/test/cathedral_outdoor
# /content/test/test/museum
# /content/test/test/attic
# /content/test/test/house
# /content/test/test/heliport
# /content/test/test/mausoleum
# /content/test/test/beauty_salon
# /content/test/test/archive
# /content/test/test/basketball_court_outdoor
# /content/test/test/library_indoor
# /content/test/test/inn
# /content/test/test/pasture
# /content/test/test/youth_hostel
# /content/test/test/topiary_garden
# /content/test/test/fairway
# /content/test/test/art_school
# /content/test/test/poolroom_establishment
# /content/test/test/underwater_coral_reef
# /content/test/test/boardwalk
# /content/test/test/hangar_outdoor
# /content/test/test/temple_south_asia
# /content/test/test/carrousel
# /content/test/test/jacuzzi
# /content/test/test/pagoda
# /content/test/test/cabin
# /content/test/test/courthouse
# /content/test/test/canal_natural
# /content/test/test/cubicle
# /content/test/test/assembly_line
# /content/test/test/sandbar
# /content/test/test/cemetery
# /content/test/test/banquet_hall
# /content/test/test/outhouse
# /content/test/test/jail
# /content/test/test/drugstore
# /content/test/test/cathedral_indoor
# /content/test/test/manufactured_home
# /content/test/test/stadium_football
# /content/test/test/ice_floe
# /content/test/test/office
# /content/test/test/hospital_room
# /content/test/test/temple_east_asia
# /content/test/test/fire_station
# /content/test/test/courtyard
# /content/test/test/motel
# /content/test/test/river
# /content/test/test/beach
# /content/test/test/shower
# /content/test/test/hotel_room
# /content/test/test/art_studio
# /content/test/test/amusement_park
# /content/test/test/industrial_area
# /content/test/test/wine_cellar_barrel_storrage
# /content/test/test/watering_hole
# /content/test/test/snowfield
# /content/test/test/auto_factory
# /content/test/test/canal_urban
# /content/test/test/vineyard
# /content/test/test/biology_laboratory
# /content/test/test/iceberg
# /content/test/test/subway_interior
# /content/test/test/baseball_field
# /content/test/test/chicken_coop_indoor
# /content/test/test/subway_station
# /content/test/test/hangar_indoor
# /content/test/test/doorway
# /content/test/test/market_outdoor
# /content/test/test/field_cultivated
# /content/test/test/ocean
# /content/test/test/kindergarden_classroom
# /content/test/test/monastery
# /content/test/test/parking_lot
# /content/test/test/butte
# /content/test/test/volleyball_court_outdoor
# /content/test/test/mansion
# /content/test/test/brewery_indoor
# /content/test/test/ice_cream_parlor
# /content/test/test/islet
# /content/test/test/parlor
# /content/test/test/home_office
# /content/test/test/aqueduct
# /content/test/test/shed
# /content/test/test/abbey
# /content/test/test/building_facade
# /content/test/test/theater_indoor_seats
# /content/test/test/pharmacy
# /content/test/test/valley
# /content/test/test/bookstore
# /content/test/test/desert_vegetation
# /content/test/test/shoe_shop
# /content/test/test/sandbox
# /content/test/test/runway
# /content/test/test/lake_natural
# /content/test/test/apartment_building_outdoor
# /content/test/test/bowling_alley
# /content/test/test/dinette_vehicle
# /content/test/test/discotheque
# /content/test/test/dining_car
# /content/test/test/courtroom
# /content/test/test/podium_indoor
# /content/test/test/construction_site
# /content/test/test/promenade_deck
# /content/test/test/driveway
# /content/test/test/cavern
# /content/test/test/bakery_shop
# /content/test/test/hotel
# /content/test/test/aquarium
# /content/test/test/greenhouse_indoor
# /content/test/test/harbor
# /content/test/test/highway
# /content/test/test/mosque_indoor
# /content/test/test/vegetable_garden
# /content/test/test/dining_room
# /content/test/test/music_studio
# /content/test/test/throne_room
# /content/test/test/pond
# /content/test/test/pilothouse
# /content/test/test/skyscraper
# /content/test/test/bridge
# /content/test/test/apse_indoor
# /content/test/test/wine_cellar_bottle_storage
# /content/test/test/control_tower
# /content/test/test/park
# /content/test/test/elevator_interior
# /content/test/test/crevasse
# /content/test/test/art_gallery
# /content/test/test/viaduct
# /content/test/test/living_room
# /content/test/test/jewelry_shop
# /content/test/test/computer_room
# /content/test/test/car_interior_frontseat
# /content/test/test/baggage_claim
# /content/test/test/swamp
# /content/test/test/stable
# /content/test/test/nuclear_power_plant
# /content/test/test/water_tower
# /content/test/test/hot_tub
# /content/test/test/firing_range
# /content/test/test/castle
# /content/test/test/plaza
# /content/test/test/stage
# /content/test/test/windmill
# /content/test/test/pantry
# /content/test/test/supermarket
# /content/test/test/yard
# /content/test/test/pavilion
# /content/test/test/picnic_area
# /content/test/test/dam
# /content/test/test/hunting_lodge
# /content/test/test/toll_plaza
# /content/test/test/library_outdoor
# /content/test/test/arrival_gate_outdoor
# /content/test/test/ski_slope
# /content/test/test/landfill
# /content/test/test/tree_house
# /content/test/test/physics_laboratory
# /content/test/test/raft
# /content/test/test/chemistry_lab
# /content/test/test/oilrig
# /content/test/test/tennis_court_indoor
# /content/test/test/amusement_arcade
# /content/test/test/train_railway
# /content/test/test/botanical_garden
# /content/test/test/forest_road
# /content/test/test/patio
# /content/test/test/garbage_dump
# /content/test/test/barn
# /content/test/test/bow_window_outdoor
# /content/test/test/trench
# /content/test/test/power_plant
# /content/test/test/conference_center
# /content/test/test/village
# /content/test/test/reception
# /content/test/test/tent
# /content/test/test/rock_arch
# /content/test/test/engine_room
# /content/test/test/bistro_indoor
# /content/test/test/street
# /content/test/test/delicatessen
# /content/test/test/dock
# /content/test/test/limousine_interior
# /content/test/test/classroom
# /content/test/test/kitchenette
# /content/test/test/orchard
# /content/test/test/chicken_coop_outdoor
# /content/test/test/hill
# /content/test/test/alley
# /content/test/test/cheese_factory
# /content/test/test/warehouse_indoor
# /content/test/test/car_interior_backseat
# /content/test/test/escavation
# /content/test/test/clothing_store
# /content/test/test/bedroom
# /content/test/test/pulpit
# /content/test/test/ice_skating_rink_outdoor
# /content/test/test/corn_field
# /content/test/test/amphitheater
# /content/test/test/lighthouse
# /content/test/test/driving_range
# /content/test/test/closet
# /content/test/test/church_outdoor
# /content/test/test/factory
# /content/test/test/fire_escape
# /content/test/test/bus_interior
# /content/test/test/volcano
# /content/test/test/palace
# /content/test/test/oast_house
# /content/test/test/ticket_booth
# /content/test/test/catacomb
# /content/test/test/lecture_room
# /content/test/test/candy_store
# /content/test/test/badlands
# /content/test/test/crosswalk
# /content/test/test/playroom
# /content/test/test/phone_booth
# /content/test/test/forest_needleleaf
# /content/test/test/hayfield
# /content/test/test/dentists_office
# /content/test/test/railroad_track
# /content/test/test/waterfall_plunge
# /content/test/test/mosque_outdoor
# /content/test/test/train_station
# /content/test/test/lock_chamber
# /content/test/test/lobby
# /content/test/test/airplane_cabin
# /content/test/test/tree_farm
# /content/test/test/garage
# /content/test/test/control_room
# /content/test/test/television_studio
# /content/test/test/slum
# /content/test/test/ski_lodge
# /content/test/test/observatory
# /content/test/test/raceway
# /content/test/test/tower
# /content/test/test/swimming_pool_indoor
# /content/test/test/laundromat
# /content/test/test/squash_court
# /content/test/test/veranda
# /content/test/test/bullring
# /content/test/test/nursery
# /content/test/test/conference_room
# /content/test/test/volleyball_court_indoor
# /content/test/test/igloo
# /content/test/test/ice_shelf
# /content/test/test/desert_sand
# /content/test/test/forest_broadleaf
# /content/test/test/golf_course
# /content/test/test/theater_indoor_procenium
# /content/test/test/riding_arena
# /content/test/test/podium_outdoor
# /content/test/test/diner_indoor
# /content/test/test/rainforest
# /content/test/test/chalet
# /content/test/test/poolroom_home
# /content/test/test/boathouse
# /content/test/test/cloister
# /content/test/test/rope_bridge
# /content/test/test/campus
# /content/test/test/gazebo
# /content/test/test/booth_indoor
# /content/test/test/operating_room
# /content/test/test/music_store
# /content/test/test/skatepark
# /content/test/test/lido_deck
# /content/test/test/ballroom
# /content/test/test/hot_spring
# /content/test/test/gymnasium
# /content/test/test/recreation_room
# /content/test/test/galley
# /content/test/test/playground
# /content/test/test/lift_bridge
# /content/test/test/basilica
# /content/test/test/market_indoor
# /content/test/test/track
# /content/test/test/martial_arts_gym
# /content/test/test/boxing_ring
# /content/test/test/parking_garage_indoor
# /content/test/test/putting_green
# /content/test/test/coast
# /content/test/test/bow_window_indoor
# /content/test/test/coffe_shop
# /content/test/test/mountain_snowy
# /content/test/test/creek
# /content/test/test/sea_cliff
# /content/test/test/moat
# /content/test/test/batters_box
# /content/test/test/videostore
# /content/test/test/planetarium
# /content/test/test/kitchen
# /content/test/test/kennel_indoor
# /content/test/test/van_interior
# /content/test/test/general_store_outdoor
# /content/test/test/restaurant_kitchen
# /content/test/test/berth
# /content/test/test/cockpit
# /content/test/test/hospital
# /content/test/test/sauna
# /content/test/test/bamboo_forest
# /content/test/test/swimming_pool_outdoor
# /content/test/test/ski_resort
# /content/test/test/rice_paddy
# /content/test/test/waterfall_block
# /content/test/test/stadium_baseball
# /content/test/test/boat_deck
# /content/test/test/ice_skating_rink_indoor
# /content/test/test/jail_cell
# /content/test/test/movie_theater
# /content/test/test/bathroom
# /content/test/test/barndoor
# /content/test/test/badminton_court_indoor
# /content/test/test/fastfood_restaurant
# /content/test/test/sushi_bar
# /content/test/test/server_room
# /content/test/test/restaurant_patio
# /content/test/test/balcony_exterior
# /content/test/test/veterinarians_office
# /content/test/test/atrium_public
# /content/test/test/diner_outdoor
# /content/test/test/burial_chamber
# /content/test/test/racecourse
# /content/test/test/electrical_substation
# /content/test/test/forest_path
# /content/test/test/waiting_room
# /content/test/test/cafeteria
# /content/test/test/general_store_indoor
# /content/test/test/restaurant
# /content/test/test/toyshop
# /content/test/test/dorm_room
# /content/test/test/cliff
# /content/test/test/kennel_outdoor
# /content/test/test/bazaar_indoor
# /content/test/test/anechoic_chamber
# /content/test/test/gift_shop
# /content/test/test/bar
# /content/test/test/shopping_mall
# /content/test/test/florist_shop
# /content/test/test/pub
# /content/test/test/balcony_interior
# /content/test/test/bazaar_outdoor
# /content/test/test/staircase
# /content/test/test/synagogue_indoor
# /content/test/test/covered_bridge
# /content/test/test/waterfall_fan
# /content/test/test/parking_garage_outdoor
# /content/test/test/elevator_door
# /content/test/test/kasbah
# /content/test/test/shopfront
# /content/test/test/labyrinth
# /content/test/test/mountain
# /content/test/test/greenhouse_outdoor
# /content/test/test/bayou
# /content/test/test/canyon
# /content/test/test/fountain
# /content/test/test/fishpond
# /content/test/test/corral
# /content/test/test/auditorium
# ['/content/test/test/athletic_field_outdoor', '/content/test/test/thriftshop', '/content/test/test/wet_bar', '/content/test/test/cottage_garden', '/content/test/test/tennis_court_outdoor', '/content/test/test/herb_garden', '/content/test/test/butchers_shop', '/content/test/test/utility_room', '/content/test/test/clean_room', '/content/test/test/oil_refinery', '/content/test/test/synagogue_outdoor', '/content/test/test/childs_room', '/content/test/test/corridor', '/content/test/test/gas_station', '/content/test/test/wrestling_ring_indoor', '/content/test/test/wind_farm', '/content/test/test/escalator', '/content/test/test/ruin', '/content/test/test/office_building', '/content/test/test/dinette_home', '/content/test/test/formal_garden', '/content/test/test/residential_neighbourhood', '/content/test/test/basement', '/content/test/test/airport_terminal', '/content/test/test/food_court', '/content/test/test/church_indoor', '/content/test/test/field_wild', '/content/test/test/wave', '/content/test/test/ball_pit', '/content/test/test/arch', '/content/test/test/locker_room', '/content/test/test/elevator_shaft', '/content/test/test/marsh', '/content/test/test/schoolhouse', '/content/test/test/medina', '/content/test/test/casino', '/content/test/test/wheat_field', '/content/test/test/landing_deck', '/content/test/test/sky', '/content/test/test/game_room', '/content/test/test/campsite', '/content/test/test/cathedral_outdoor', '/content/test/test/museum', '/content/test/test/attic', '/content/test/test/house', '/content/test/test/heliport', '/content/test/test/mausoleum', '/content/test/test/beauty_salon', '/content/test/test/archive', '/content/test/test/basketball_court_outdoor', '/content/test/test/library_indoor', '/content/test/test/inn', '/content/test/test/pasture', '/content/test/test/youth_hostel', '/content/test/test/topiary_garden', '/content/test/test/fairway', '/content/test/test/art_school', '/content/test/test/poolroom_establishment', '/content/test/test/underwater_coral_reef', '/content/test/test/boardwalk', '/content/test/test/hangar_outdoor', '/content/test/test/temple_south_asia', '/content/test/test/carrousel', '/content/test/test/jacuzzi', '/content/test/test/pagoda', '/content/test/test/cabin', '/content/test/test/courthouse', '/content/test/test/canal_natural', '/content/test/test/cubicle', '/content/test/test/assembly_line', '/content/test/test/sandbar', '/content/test/test/cemetery', '/content/test/test/banquet_hall', '/content/test/test/outhouse', '/content/test/test/jail', '/content/test/test/drugstore', '/content/test/test/cathedral_indoor', '/content/test/test/manufactured_home', '/content/test/test/stadium_football', '/content/test/test/ice_floe', '/content/test/test/office', '/content/test/test/hospital_room', '/content/test/test/temple_east_asia', '/content/test/test/fire_station', '/content/test/test/courtyard', '/content/test/test/motel', '/content/test/test/river', '/content/test/test/beach', '/content/test/test/shower', '/content/test/test/hotel_room', '/content/test/test/art_studio', '/content/test/test/amusement_park', '/content/test/test/industrial_area', '/content/test/test/wine_cellar_barrel_storrage', '/content/test/test/watering_hole', '/content/test/test/snowfield', '/content/test/test/auto_factory', '/content/test/test/canal_urban', '/content/test/test/vineyard', '/content/test/test/biology_laboratory', '/content/test/test/iceberg', '/content/test/test/subway_interior', '/content/test/test/baseball_field', '/content/test/test/chicken_coop_indoor', '/content/test/test/subway_station', '/content/test/test/hangar_indoor', '/content/test/test/doorway', '/content/test/test/market_outdoor', '/content/test/test/field_cultivated', '/content/test/test/ocean', '/content/test/test/kindergarden_classroom', '/content/test/test/monastery', '/content/test/test/parking_lot', '/content/test/test/butte', '/content/test/test/volleyball_court_outdoor', '/content/test/test/mansion', '/content/test/test/brewery_indo ...

# %%
for i in all_test_filenames[:297]:
    shutil.rmtree(i)

# %%
valid_path = '/content/test/test'

test_folders = glob(valid_path+ '/*')

len(test_folders)
# Out:
# 100

# %% [markdown]
# # USING RESNET

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
import itertools

# %%
# re-size all the images to this
IMAGE_SIZE = [160, 160] # feel free to change depending on dataset

# training config:
epochs = 8
batch_size = 140

# %%
train_path = '/content/train/train'
valid_path = '/content/test/test'

# %%
# useful for getting number of files
image_files = glob(train_path + '/*/*.jp*g')
valid_image_files = glob(valid_path + '/*/*.jp*g')

# %%
# useful for getting number of classes
folders = glob(train_path + '/*')

# %%
# look at an image for fun
plt.imshow(image.load_img(np.random.choice(image_files)));

# %%
len(folders)
# Out:
# 100

# %%
# resnet base
res = ResNet50(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
# don't train existing weights
for layer in res.layers:
    layer.trainable = False

# %%
# our layers - you can add more if you want
x = Flatten()(res.output)
# x = Dense(1000, activation='relu')(x) # example
prediction = Dense(len(folders), activation='softmax')(x)

# %%
# create a model object
model = Model(inputs=res.input, outputs=prediction)

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 166, 166, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 80, 80, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 80, 80, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 80, 80, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 82, 82, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 40, 40, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 40, 40, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 40, 40, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 40, 40, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 40, 40, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 40, 40, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 40, 40, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 40, 40, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 40, 40, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 40, 40, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 40, 40, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 40, 40, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 40, 40, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 40, 40, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 40, 40, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 40, 40, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 40, 40, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 40, 40, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 40, 40, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 40, 40, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 40, 40, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 40, 40, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 40, 40, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 40, 40, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 40, 40, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 40, 40, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 40, 40, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 40, 40, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 40, 40, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 40, 40, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 40, 40, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 40, 40, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 40, 40, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 20, 20, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 20, 20, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 20, 20, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 20, 20, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 20, 20, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 20, 20, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 20, 20, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 20, 20, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 20, 20, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 20, 20, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 20, 20, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 20, 20, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 20, 20, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 20, 20, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 20, 20, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 20, 20, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 20, 20, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 20, 20, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 20, 20, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 20, 20, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 20, 20, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 20, 20, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 20, 20, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 20, 20, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 20, 20, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 20, 20, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 20, 20, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 20, 20, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 20, 20, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 20, 20, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 20, 20, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 20, 20, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 20, 20, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 20, 20, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 20, 20, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 20, 20, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 20, 20, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 20, 20, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 20, 20, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 20, 20, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 20, 20, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 20, 20, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 10, 10, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 10, 10, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 10, 10, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 10, 10, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 10, 10, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 10, 10, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 10, 10, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 10, 10, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 10, 10, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 10, 10, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 10, 10, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 10, 10, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 10, 10, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 10, 10, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 10, 10, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 10, 10, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 10, 10, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 10, 10, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 10, 10, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 10, 10, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 10, 10, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 10, 10, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 10, 10, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 10, 10, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 10, 10, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 10, 10, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 10, 10, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 10, 10, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 10, 10, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 10, 10, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 10, 10, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 10, 10, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 10, 10, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 10, 10, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 10, 10, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 10, 10, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 10, 10, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 10, 10, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 10, 10, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 10, 10, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 5, 5, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 5, 5, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 5, 5, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 5, 5, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 5, 5, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 5, 5, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 5, 5, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 5, 5, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 5, 5, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 5, 5, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 5, 5, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 5, 5, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 5, 5, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 5, 5, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 5, 5, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 5, 5, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 5, 5, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 5, 5, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 5, 5, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 5, 5, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 5, 5, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 5, 5, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 5, 5, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 5, 5, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 5, 5, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 5, 5, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 5, 5, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 5, 5, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 5, 5, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 5, 5, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 5, 5, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 5, 5, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten (Flatten)              (None, 51200)        0           ['conv5_block3_out[0][0]']
#
#  dense (Dense)                  (None, 100)          5120100     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 28,707,812
# Trainable params: 5,120,100
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='sparse_categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# create an instance of ImageDataGenerator
train_gen = ImageDataGenerator(
  rotation_range=20,
  width_shift_range=0.1,
  height_shift_range=0.1,
  shear_range=0.1,
  zoom_range=0.2,
  horizontal_flip=True,
  vertical_flip=True,
  preprocessing_function=preprocess_input
)

val_gen = ImageDataGenerator(
  preprocessing_function=preprocess_input
)

# %%
# test generator to see how it works and some other useful things

# get label mapping for confusion matrix plot later
test_gen = val_gen.flow_from_directory(valid_path, target_size=IMAGE_SIZE)
print(test_gen.class_indices)
labels = [None] * len(test_gen.class_indices)
for k, v in test_gen.class_indices.items():
    labels[v] = k
# Out:
# Found 5038 images belonging to 100 classes.
# {'anechoic_chamber': 0, 'atrium_public': 1, 'auditorium': 2, 'badminton_court_indoor': 3, 'balcony_exterior': 4, 'balcony_interior': 5, 'ballroom': 6, 'bamboo_forest': 7, 'bar': 8, 'barndoor': 9, 'basilica': 10, 'bathroom': 11, 'batters_box': 12, 'bayou': 13, 'bazaar_indoor': 14, 'bazaar_outdoor': 15, 'berth': 16, 'boat_deck': 17, 'booth_indoor': 18, 'bow_window_indoor': 19, 'boxing_ring': 20, 'burial_chamber': 21, 'cafeteria': 22, 'campus': 23, 'canyon': 24, 'cliff': 25, 'coast': 26, 'cockpit': 27, 'coffe_shop': 28, 'corral': 29, 'covered_bridge': 30, 'creek': 31, 'diner_outdoor': 32, 'dorm_room': 33, 'electrical_substation': 34, 'elevator_door': 35, 'fastfood_restaurant': 36, 'fishpond': 37, 'florist_shop': 38, 'forest_path': 39, 'fountain': 40, 'galley': 41, 'gazebo': 42, 'general_store_indoor': 43, 'general_store_outdoor': 44, 'gift_shop': 45, 'greenhouse_outdoor': 46, 'gymnasium': 47, 'hospital': 48, 'hot_spring': 49, 'ice_skating_rink_indoor': 50, 'jail_cell': 51, 'kasbah': 52, 'kennel_indoor': 53, 'kennel_outdoor': 54, 'kitchen': 55, 'labyrinth': 56, 'lido_deck': 57, 'lift_bridge': 58, 'market_indoor': 59, 'martial_arts_gym': 60, 'moat': 61, 'mountain': 62, 'mountain_snowy': 63, 'movie_theater': 64, 'music_store': 65, 'operating_room': 66, 'parking_garage_indoor': 67, 'parking_garage_outdoor': 68, 'planetarium': 69, 'playground': 70, 'pub': 71, 'putting_green': 72, 'racecourse': 73, 'recreation_room': 74, 'restaurant': 75, 'restaurant_kitchen': 76, 'restaurant_patio': 77, 'rice_paddy': 78, 'rope_bridge': 79, 'sauna': 80, 'sea_cliff': 81, 'server_room': 82, 'shopfront': 83, 'shopping_mall': 84, 'skatepark': 85, 'ski_resort': 86, 'stadium_baseball': 87, 'staircase': 88, 'sushi_bar': 89, 'swimming_pool_outdoor': 90, 'synagogue_indoor': 91, 'toyshop': 92, 'track': 93, 'van_interior': 94, 'veterinarians_office': 95, 'videostore': 96, 'waiting_room': 97, 'waterfall_block': 98, 'waterfall_fan': 99}

# %%
# should be a strangely colored image (due to VGG weights being BGR)
for x, y in test_gen:
    print("min:", x[0].min(), "max:", x[0].max())
    plt.title(labels[np.argmax(y[0])])
    plt.imshow(x[0])
    plt.show()
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# min: -116.779 max: 138.22101

# %%
# create generators
train_generator = train_gen.flow_from_directory(
  train_path,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
  class_mode='sparse',
)
valid_generator = val_gen.flow_from_directory(
  valid_path,
  target_size=IMAGE_SIZE,
  shuffle=False,
  batch_size=batch_size,
  class_mode='sparse',
)
# Out:
# Found 4962 images belonging to 100 classes.
# Found 5038 images belonging to 100 classes.

# %%
# fit the model
r = model.fit(
  train_generator,
  validation_data=valid_generator,
  epochs=epochs,
  steps_per_epoch=len(image_files) // batch_size,
  validation_steps=len(valid_image_files) // batch_size,
)
# Out:
# Epoch 1/8
# 35/35 [==============================] - 1005s 29s/step - loss: 16.2849 - accuracy: 0.2524 - val_loss: 9.8061 - val_accuracy: 0.4482
# Epoch 2/8
# 35/35 [==============================] - 990s 29s/step - loss: 7.4224 - accuracy: 0.5041 - val_loss: 7.8422 - val_accuracy: 0.5288
# Epoch 3/8
# 35/35 [==============================] - 980s 28s/step - loss: 5.8798 - accuracy: 0.5917 - val_loss: 8.8565 - val_accuracy: 0.5269
# Epoch 4/8
# 35/35 [==============================] - 984s 28s/step - loss: 4.8811 - accuracy: 0.6553 - val_loss: 9.3259 - val_accuracy: 0.5343
# Epoch 5/8
# 35/35 [==============================] - 971s 28s/step - loss: 4.8594 - accuracy: 0.6682 - val_loss: 9.3140 - val_accuracy: 0.5549
# Epoch 6/8
# 35/35 [==============================] - 979s 28s/step - loss: 4.7986 - accuracy: 0.6900 - val_loss: 9.8526 - val_accuracy: 0.5594
# Epoch 7/8
# 35/35 [==============================] - 983s 28s/step - loss: 4.1391 - accuracy: 0.7298 - val_loss: 9.4544 - val_accuracy: 0.5727
# Epoch 8/8
# 35/35 [==============================] - 976s 28s/step - loss: 3.8677 - accuracy: 0.7470 - val_loss: 10.5645 - val_accuracy: 0.5684

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.21.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)

# %%
model.save('my_model.h5')

# %%
# loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# accuracies
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend();

# %%
def get_confusion_matrix(data_path, N):
  # we need to see the data in the same order
  # for both predictions and targets
    print("Generating confusion matrix", N)
    predictions = []
    targets = []
    i = 0
    n_images = 0
    for x, y in val_gen.flow_from_directory(
      data_path,
      target_size=IMAGE_SIZE,
      shuffle=False,
      batch_size=batch_size * 2):
        i += 1
        n_images += len(y)
        if i % 50 == 0:
            print(f'{n_images} images processed.')
        p = model.predict(x)
        p = np.argmax(p, axis=1)
        y = np.argmax(y, axis=1)
        predictions = np.concatenate((predictions, p))
        targets = np.concatenate((targets, y))
        if len(targets) >= N:
            break

    cm = confusion_matrix(targets, predictions)
    return cm

# %%
cm = get_confusion_matrix(train_path, len(image_files))
print(cm)
# Out:
# Generating confusion matrix 4962
# Found 4962 images belonging to 100 classes.
# [[54  0  0 ...  0  0  0]
#  [ 0 39  0 ...  0  0  0]
#  [ 0  0 48 ...  0  0  0]
#  ...
#  [ 0  0  1 ... 32  0  0]
#  [ 0  0  0 ...  0 45  0]
#  [ 0  0  0 ...  0 11 31]]

# %%
valid_cm = get_confusion_matrix(valid_path, len(valid_image_files))
print(valid_cm)
# Out:
# Generating confusion matrix 5038
# Found 5038 images belonging to 100 classes.
# [[29  1  0 ...  0  0  0]
#  [ 2 17  0 ...  0  0  0]
#  [ 1  0 42 ...  0  0  0]
#  ...
#  [ 0  0  2 ...  4  0  0]
#  [ 0  0  0 ...  0 49  1]
#  [ 0  0  0 ...  0 26 21]]

# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
# class_names = train_dataset.class_names

# dimensions of our images
img_width, img_height = 160, 160

# load the model we saved
model2 = load_model('my_model.h5')
model2.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# predicting images
img = image.load_img('/content/scene 1.jpg', target_size=(img_width,img_height))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model2.predict(x, batch_size=140)
index = np.argmax(classes,axis=1)[0]
print(labels[index])
# Out:
# cafeteria

# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np

# dimensions of our images
img_width, img_height = 160, 160

# load the model we saved
model2 = load_model('my_model.h5')
model2.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# predicting images
img = image.load_img('/content/scene 2.jpg', target_size=(img_width,img_height))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model2.predict(x, batch_size=140)
index = np.argmax(classes,axis=1)[0]
print(labels[index])
# Out:
# WARNING:tensorflow:6 out of the last 71 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc7ce31830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# elevator_door

# %%
def predict_scene(img_path = ''):
    from keras.models import load_model
    from keras.preprocessing import image
    import numpy as np

    # dimensions of our images
    img_width, img_height = 160, 160

    # load the model we saved
    model2 = load_model('my_model.h5')
    model2.compile(loss='sparse_categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])

    # predicting images
    img = image.load_img(img_path, target_size=(img_width,img_height))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    images = np.vstack([x])
    classes = model2.predict(x, batch_size=140)
    index = np.argmax(classes,axis=1)[0]
    print(labels[index])

# %%
predict_scene('/content/scene 3.jpg')
# Out:
# kitchen

# %%
labels
# Out:
# ['anechoic_chamber',
#  'atrium_public',
#  'auditorium',
#  'badminton_court_indoor',
#  'balcony_exterior',
#  'balcony_interior',
#  'ballroom',
#  'bamboo_forest',
#  'bar',
#  'barndoor',
#  'basilica',
#  'bathroom',
#  'batters_box',
#  'bayou',
#  'bazaar_indoor',
#  'bazaar_outdoor',
#  'berth',
#  'boat_deck',
#  'booth_indoor',
#  'bow_window_indoor',
#  'boxing_ring',
#  'burial_chamber',
#  'cafeteria',
#  'campus',
#  'canyon',
#  'cliff',
#  'coast',
#  'cockpit',
#  'coffe_shop',
#  'corral',
#  'covered_bridge',
#  'creek',
#  'diner_outdoor',
#  'dorm_room',
#  'electrical_substation',
#  'elevator_door',
#  'fastfood_restaurant',
#  'fishpond',
#  'florist_shop',
#  'forest_path',
#  'fountain',
#  'galley',
#  'gazebo',
#  'general_store_indoor',
#  'general_store_outdoor',
#  'gift_shop',
#  'greenhouse_outdoor',
#  'gymnasium',
#  'hospital',
#  'hot_spring',
#  'ice_skating_rink_indoor',
#  'jail_cell',
#  'kasbah',
#  'kennel_indoor',
#  'kennel_outdoor',
#  'kitchen',
#  'labyrinth',
#  'lido_deck',
#  'lift_bridge',
#  'market_indoor',
#  'martial_arts_gym',
#  'moat',
#  'mountain',
#  'mountain_snowy',
#  'movie_theater',
#  'music_store',
#  'operating_room',
#  'parking_garage_indoor',
#  'parking_garage_outdoor',
#  'planetarium',
#  'playground',
#  'pub',
#  'putting_green',
#  'racecourse',
#  'recreation_room',
#  'restaurant',
#  'restaurant_kitchen',
#  'restaurant_patio',
#  'rice_paddy',
#  'rope_bridge',
#  'sauna',
#  'sea_cliff',
#  'server_room',
#  'shopfront',
#  'shopping_mall',
#  'skatepark',
#  'ski_resort',
#  'stadium_baseball',
#  'staircase',
#  'sushi_bar',
#  'swimming_pool_outdoor',
#  'synagogue_indoor',
#  'toyshop',
#  'track',
#  'van_interior',
#  'veterinarians_office',
#  'videostore',
#  'waiting_room',
#  'waterfall_block',
#  'waterfall_fan']
